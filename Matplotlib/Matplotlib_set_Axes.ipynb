# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
x=np.arange(0.0,5.0,0.02)  # 0~5 步长为0.02
x
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#        0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#        0.88, 0.9 , 0.92, 0.94, 0.96, 0.98, 1.  , 1.02, 1.04, 1.06, 1.08,
#        1.1 , 1.12, 1.14, 1.16, 1.18, 1.2 , 1.22, 1.24, 1.26, 1.28, 1.3 ,
#        1.32, 1.34, 1.36, 1.38, 1.4 , 1.42, 1.44, 1.46, 1.48, 1.5 , 1.52,
#        1.54, 1.56, 1.58, 1.6 , 1.62, 1.64, 1.66, 1.68, 1.7 , 1.72, 1.74,
#        1.76, 1.78, 1.8 , 1.82, 1.84, 1.86, 1.88, 1.9 , 1.92, 1.94, 1.96,
#        1.98, 2.  , 2.02, 2.04, 2.06, 2.08, 2.1 , 2.12, 2.14, 2.16, 2.18,
#        2.2 , 2.22, 2.24, 2.26, 2.28, 2.3 , 2.32, 2.34, 2.36, 2.38, 2.4 ,
#        2.42, 2.44, 2.46, 2.48, 2.5 , 2.52, 2.54, 2.56, 2.58, 2.6 , 2.62,
#        2.64, 2.66, 2.68, 2.7 , 2.72, 2.74, 2.76, 2.78, 2.8 , 2.82, 2.84,
#        2.86, 2.88, 2.9 , 2.92, 2.94, 2.96, 2.98, 3.  , 3.02, 3.04, 3.06,
#        3.08, 3.1 , 3.12, 3.14, 3.16, 3.18, 3.2 , 3.22, 3.24, 3.26, 3.28,
#        3.3 , 3.32, 3.34, 3.36, 3.38, 3.4 , 3.42, 3.44, 3.46, 3.48, 3.5 ,
#        3.52, 3.54, 3.56, 3.58, 3.6 , 3.62, 3.64, 3.66, 3.68, 3.7 , 3.72,
#        3.74, 3.76, 3.78, 3.8 , 3.82, 3.84, 3.86, 3.88, 3.9 , 3.92, 3.94,
#        3.96, 3.98, 4.  , 4.02, 4.04, 4.06, 4.08, 4.1 , 4.12, 4.14, 4.16,
#        4.18, 4.2 , 4.22, 4.24, 4.26, 4.28, 4.3 , 4.32, 4.34, 4.36, 4.38,
#        4.4 , 4.42, 4.44, 4.46, 4.48, 4.5 , 4.52, 4.54, 4.56, 4.58, 4.6 ,
#        4.62, 4.64, 4.66, 4.68, 4.7 , 4.72, 4.74, 4.76, 4.78, 4.8 , 4.82,
#        4.84, 4.86, 4.88, 4.9 , 4.92, 4.94, 4.96, 4.98])

# %%
y=np.exp(-x)*np.cos(2*np.pi*x)
plt.plot(x,y)
plt.grid(color='gold')

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.grid(color='gray')  # 网格
ax.plot(x,y)

# %%
# 坐标轴
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
ax.grid(color='pink') 
ax.set_xlabel('x axis')  # 设置x轴标题
ax.set_xlim((-2,10))  # 设置x轴范围
ax.set_xticks(np.linspace(0,5,11))  # 细化x轴的标签
# Out:
# [<matplotlib.axis.XTick at 0x1d18f0030b8>,
#  <matplotlib.axis.XTick at 0x1d18efff9b0>,
#  <matplotlib.axis.XTick at 0x1d18efff6d8>,
#  <matplotlib.axis.XTick at 0x1d18f025278>,
#  <matplotlib.axis.XTick at 0x1d18f025748>,
#  <matplotlib.axis.XTick at 0x1d18f025c18>,
#  <matplotlib.axis.XTick at 0x1d18f02c160>,
#  <matplotlib.axis.XTick at 0x1d18f02c5f8>,
#  <matplotlib.axis.XTick at 0x1d18f02cb38>,
#  <matplotlib.axis.XTick at 0x1d18f0330f0>,
#  <matplotlib.axis.XTick at 0x1d18f0335f8>]

# %%
ax=plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
from sklearn.datasets import fetch_olivetti_faces
faces=fetch_olivetti_faces().images
# faces
fig,ax=plt.subplots(5,5,figsize=(5,5))
fig.subplots_adjust(hspace=0,wspace=0)
for i in range(5):
    for j in range(5):
        ax[i,j].xaxis.set_major_locator(plt.NullLocator())
        ax[i,j].yaxis.set_major_locator(plt.NullLocator())
        ax[i,j].imshow(faces[10*i+j],cmap='bone')

# %%
fig,ax=plt.subplots(3,2)
